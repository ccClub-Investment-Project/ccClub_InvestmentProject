# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

url = 'https://www.taifex.com.tw/cht/3/futDailyMarketReport?queryType=2&marketCode=0&dateaddcnt=&commodity_id=TX&commodity_id2=&queryDate=2023%2F08%2F07&MarketCode=0&commodity_idt=TX&commodity_id2t=&commodity_id2t2='
res = requests.get(url)
soup = bs(res.text, 'lxml')
tb = soup.select('table')
df = pd.read_html(tb[].prettify())
df[0]
# Out:
#   價差對價差成交                                                                \
#        契約     到期月份  (週別)  開盤價  最高價  最低價 最後成交價 最後最佳買價 最後最佳賣價 歷史最高價 歷史最低價
# 0      TX  202308/202309  -31  -31  -39   -35  -37.0  -35.0   -13   -39
# 1      TX  202308/202310    -    -    -     -  -58.0  -55.0   -33   -58
# 2      TX  202308/202312    -    -    -     -  -98.0  -95.0   -80   -99
# 3      TX  202308/202403    -    -    -     - -162.0 -156.0     -     -
# 4      TX  202308/202406    -    -    -     - -249.0 -243.0     -     -
# 5      TX  202309/202406    -    -    -     - -214.0 -199.0  -151  -152
# 6      TX  202312/202403    -    -    -     -  -67.0   50.0   -42   -61
# 7     NaN            NaN  NaN  NaN  NaN   NaN    NaN    NaN   NaN   小計:
#
#                   價差對單式成交
#   價差對價差  成交量 價差對單式委託  成交量
# 0         32         1072
# 1          0           61
# 2          0           25
# 3          0           10
# 4          0           74
# 5          0            1
# 6          0            2
# 7         32         1245

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from io import StringIO

url = 'https://www.taifex.com.tw/cht/3/futDailyMarketReport'
payload = {
    'marketCode': 0,
    'commodity_id': 'TX',
    'queryDate': '2023/08/01'
}
res = requests.get(url, params=payload)
soup = bs(res.text, 'lxml')
tb = soup.select('table')
table_html = StringIO(tb[1].prettify())
df = pd.read_html(table_html)
print(df[0])
# Out:
#   價差對價差成交                                                                \
#        契約     到期月份  (週別)  開盤價  最高價  最低價 最後成交價 最後最佳買價 最後最佳賣價 歷史最高價 歷史最低價
# 0      TX  202308/202309  -37  -35  -37   -35    -39  -36.0   -13   -38
# 1      TX  202308/202310    -    -    -     -    -62  -58.0   -33   -33
# 2      TX  202308/202312    -    -    -     -   -103  -99.0   -80   -94
# 3      TX  202308/202403    -    -    -     -   -166 -160.0     -     -
# 4      TX  202308/202406    -    -    -     -   -258 -250.0     -     -
# 5      TX  202309/202310    -    -    -     -    -25  -20.0   -11   -17
# 6      TX  202310/202312    -    -    -     -      -  -40.0     -     -
# 7     NaN            NaN  NaN  NaN  NaN   NaN    NaN    NaN   NaN   小計:
#
#                   價差對單式成交
#   價差對價差  成交量 價差對單式委託  成交量
# 0          5          459
# 1          0           34
# 2          0           13
# 3          0           44
# 4          0            3
# 5          0           11
# 6          0            3
# 7          5          567

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

url = 'https://www.taifex.com.tw/cht/3/futDailyMarketReport'
payload = {
    'marketCode':0,
    'commodity_id':'TX',
    'queryDate':'2023/08/01'
}
payload['queryDate'] = '2023/08/01'
res = requests.post(url, data = payload)
soup = bs(res.text, 'lxml')
tb = soup.select('table')
df = pd.read_html(tb[4].prettify())
df[0]

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

url = 'https://www.taifex.com.tw/cht/3/futDailyMarketReport?queryType=2&marketCode=0&dateaddcnt=&commodity_id=TX&commodity_id2=&queryDate=2023%2F08%2F07&MarketCode=0&commodity_idt=TX&commodity_id2t=&commodity_id2t2='
res = requests.get(url)
df = pd.read_html(res.text)
df[4]
# Out:
#     契約  到期 月份 (週別)      開盤價      最高價      最低價   最後 成交價   漲跌價     漲跌%  \
# 0   TX    202308.0  16859.0  17027.0  16836.0  17002.0  ▲179  ▲1.06%
# 1   TX    202309.0  16818.0  16989.0  16809.0  16960.0  ▲167  ▲0.99%
# 2   TX    202310.0  16794.0  16965.0  16790.0  16932.0  ▲163  ▲0.97%
# 3   TX    202312.0  16763.0  16922.0  16762.0  16922.0  ▲191  ▲1.14%
# 4   TX    202403.0  16695.0  16860.0  16695.0  16860.0  ▲193  ▲1.16%
# 5   TX    202406.0  16606.0  16765.0  16602.0  16764.0  ▲185  ▲1.12%
# 6  NaN         NaN      NaN      NaN      NaN      NaN   NaN     小計:
#
#    *盤後交易時段成交量  *一般交易時段成交量  *合計成交量      結算價  *未沖銷契約量   最後最佳買價   最後最佳賣價  \
# 0       70189       93476  163665  17000.0    73569  17002.0  17003.0
# 1        1067        1318    2385  16960.0     3233  16965.0  16968.0
# 2          29          62      91  16946.0      234  16944.0  16948.0
# 3          23          26      49  16906.0      481  16904.0  16908.0
# 4          12          12      24  16843.0      486  16840.0  16847.0
# 5          52          76     128  16764.0       89  16753.0  16760.0
# 6       71372       94970  166342      NaN    78092      NaN      NaN
#
#      歷史最高價    歷史最低價
# 0  17425.0  15631.0
# 1  17386.0  11969.0
# 2  17360.0  16608.0
# 3  17310.0  13257.0
# 4  17258.0  14451.0
# 5  17122.0  16330.0
# 6      NaN      NaN

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta

url = 'https://www.taifex.com.tw/cht/3/futDailyMarketReport'
payload = {
    'marketCode':0,
    'commodity_id':'TX',
    'queryDate':'2023/08/01'
}
l = []
base = dt.datetime.today() - relativedelta(days = 7)
while base < dt.datetime.today():
    date = base.strftime('%Y/%m/%d')
    print(date)
    payload['queryDate'] = date
    res = requests.post(url, data = payload)
    if res.text.find('查無資料') > -1:
        base = base + relativedelta(days = 1)
        continue
    soup = bs(res.text, 'lxml')
    tb = soup.select('table')
    df = pd.read_html(tb[4].prettify())
    df[0].insert(0, '日期', date)
    l.append(df[0])    
    base = base + relativedelta(days = 1)
# Out:
# 2023/08/01
# 2023/08/02
# 2023/08/03
# 2023/08/04
# 2023/08/05
# 2023/08/06
# 2023/08/07
# 2023/08/08

# %%
df0 = pd.concat(l, ignore_index = True)
df0 = df0[df0['契約'].isna() == False]
df0 = df0.reset_index(drop = True)
df0.to_csv('123.csv', encoding = 'Big5')
df0.to_excel('123.xlsx')
df0
# Out:
#             日期  契約  到期  月份  (週別)      開盤價      最高價      最低價  最後  成交價    漲跌價  \
